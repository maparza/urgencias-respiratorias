# %%
import pandas as pd

# %%
df = pd.read_parquet("data/at_urg_respiratorio_semanal.parquet")

# %%
df.shape
# Out:
# (3640132, 25)

# %%
df.columns.tolist()
# Out:
# ['EstablecimientoCodigo',
#  'EstablecimientoGlosa',
#  'RegionCodigo',
#  'RegionGlosa',
#  'ComunaCodigo',
#  'ComunaGlosa',
#  'ServicioSaludCodigo',
#  'ServicioSaludGlosa',
#  'TipoEstablecimiento',
#  'DependenciaAdministrativa',
#  'NivelAtencion',
#  'TipoUrgencia',
#  'Latitud',
#  'Longitud',
#  'NivelComplejidad',
#  'Anio',
#  'SemanaEstadistica',
#  'OrdenCausa',
#  'Causa',
#  'NumTotal',
#  'NumMenor1Anio',
#  'Num1a4Anios',
#  'Num5a14Anios',
#  'Num15a64Anios',
#  'Num65oMas']

# %%
df.head()
# Out:
#   EstablecimientoCodigo                               EstablecimientoGlosa  \
# 0                110860                                          SAR Renca
# 1                200143                                     SAPU Aguilucho
# 2                200094                 SAPU Marco Antonio Carvajal Moreno
# 3                117107  Hospital Comunitario de Salud Familiar de El C...
# 4                121806                                    SAPU Santa Rosa
#
#   RegionCodigo                       RegionGlosa ComunaCodigo  ComunaGlosa  \
# 0           13  Región Metropolitana de Santiago        13128        Renca
# 1           13  Región Metropolitana de Santiago        13123  Providencia
# 2           15        Región De Arica Parinacota        15101        Arica
# 3           16                   Región De Ñuble        16104    El Carmen
# 4            9            Región De La Araucanía         9101       Temuco
#
# ...
